# %%
import pickle

data_path = '/data/runkai/DPSDA/results/image/cifar10_eps=1_5k/checkpoint/000000019/data_frame.pkl'
with open(data_path, 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
#                                                PE.IMAGE  PE.IMAGE_MODEL_LABEL  \
# 0     [[[239, 239, 240], [239, 239, 240], [238, 238,...                   895
# 1     [[[71, 75, 90], [69, 74, 88], [69, 73, 88], [5...                   404
# 2     [[[96, 120, 138], [96, 120, 138], [96, 120, 13...                   895
# 3     [[[134, 134, 129], [133, 134, 129], [134, 134,...                   744
# 4     [[[45, 57, 72], [42, 54, 69], [42, 54, 70], [4...                   404
# ...                                                 ...                   ...
# 4995  [[[42, 60, 57], [53, 82, 91], [38, 58, 52], [3...                   864
# 4996  [[[101, 67, 69], [107, 69, 69], [111, 80, 82],...                   555
# 4997  [[[255, 255, 255], [255, 255, 255], [255, 255,...                   864
# 4998  [[[252, 251, 250], [251, 250, 250], [250, 249,...                   864
# 4999  [[[46, 33, 20], [51, 41, 29], [59, 47, 30], [6...                   864
#
#       PE.LABEL_ID  PE.PARENT_SYN_DATA_INDEX  PE.FROM_LAST_FLAG
# 0               0                       429                  0
# 1               0                        48                  0
# 2               0                       379                  0
# 3               0                       213                  0
# 4               0                       232                  0
# ...           ...                       ...                ...
# 4995            9                      4959                  0
# 4996            9                      4558                  0
# 4997            9                      4692                  0
# 4998            9                      4625                  0
# 4999            9                      4571                  0
#
# [5000 rows x 5 columns]
